# %% [markdown]
# Q1. List any five functions of the pandas library with execution.

# %% [markdown]
# read_csv to read the csv file

# %%
#import pandas
import pandas as pd

#read the file
pf = pd.read_csv("services.csv")

#print file
pf
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %% [markdown]
# head()  is used to read the first five records

# %%
pf.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %% [markdown]
# describe() is used to generate descriptive statistics of the data in a Pandas

# %%
pf.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %% [markdown]
# memory_usage() returns a Pandas Series having the memory usage of each column (in bytes) in a Pandas

# %%
pf.memory_usage()
# Out:
# Index                      128
# id                         184
# location_id                184
# program_id                 184
# accepted_payments          184
# alternate_name             184
# application_process        184
# audience                   184
# description                184
# eligibility                184
# email                      184
# fees                       184
# funding_sources            184
# interpretation_services    184
# keywords                   184
# languages                  184
# name                       184
# required_documents         184
# service_areas              184
# status                     184
# wait_time                  184
# website                    184
# taxonomy_ids               184
# dtype: int64

# %% [markdown]
# loc[:] helps to access a group of rows and columns in a dataset, a slice of the dataset, as per our requirement.

# %%
pf.loc[3:9,["email" , "name",'service_areas']]
# Out:
#   email                                  name  \
# 3   NaN              Family Visitation Center
# 4   NaN     Economic Self-Sufficiency Program
# 5   NaN  Little House Recreational Activities
# 6   NaN      Rosener House Adult Day Services
# 7   NaN        Meals on Wheels - South County
# 8   NaN                      Fair Oaks Branch
# 9   NaN                          Main Library
#
#                          service_areas
# 3                     San Mateo County
# 4                     San Mateo County
# 5                     San Mateo County
# 6  Belmont, Burlingame, East Palo Alto
# 7              Belmont, East Palo Alto
# 8                     San Mateo County
# 9                     San Mateo County

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
#import pandas and numpy
import pandas as pd

import numpy as np

#make the column
col = [ "A","B" ,'C']
index = [1 , 2 , 3]

#create dataframe
pf1 = pd.DataFrame(np.random.rand(3, 3 ) ,
                   columns = col , index = index )
#print pf1
pf1

#reindexing
print('\n\nDataframe after reindexing rows: \n',
pf1.reindex([1 , 3 , 5]))
# Out:
# Dataframe after reindexing rows:
#            A         B         C
# 1  0.269964  0.206898  0.098020
# 3  0.499884  0.725118  0.813123
# 5       NaN       NaN       NaN

# %% [markdown]
# Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.
#
# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should calculate and print the sum of the first three values, which is 60.

# %%
#import pandas and numpy 
import pandas as pd
import numpy as np

#create column
Values = {'Values': [ 12 , 23, 43, 38 , 64]}


#creatae dataframe
df = pd.DataFrame(Values)

#print dataframe
print(df)

#print the first three values sum
print( "the sum of first  three values", df.iloc[0:3].sum())
# Out:
#    Values
# 0      12
# 1      23
# 2      43
# 3      38
# 4      64
# the sum of first  three values Values    78
# dtype: int64

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
#import pandas
import pandas as pd

#create DataFrame
df = pd.DataFrame({'Text' : [ "aniekt",  "rakeshsharma" ,"muskanbhardwaj" ,
                              "dipikapadukon" , "riteshagarwal"]})

df
# Out:
#              Text
# 0          aniekt
# 1    rakeshsharma
# 2  muskanbhardwaj
# 3   dipikapadukon
# 4   riteshagarwal

# %%
#function to show words in text column
df["Word_Count"] = df["Text"].apply(len)

# %%
df
# Out:
#              Text  Word_Count
# 0          aniekt           6
# 1    rakeshsharma          12
# 2  muskanbhardwaj          14
# 3   dipikapadukon          13
# 4   riteshagarwal          13

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# ans - The DataFrame.size() property is used to get an int representing the number of elements in this object and Return the number of rows if Series. Otherwise, return the number of rows times the number of columns if DataFrame.
#
#
# and The DataFrame.shape() property is used to get a tuple representing the dimensionality of the Pandas DataFrame.

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
#import pandas 
import pandas as pd

#create column
data1 = {'Email' : ["aniketa@gmail.com" ,"rohitroy@gamil.com", "ranjeetarora@gmail.com" ,
                     "Kapilsharma@gmail.com" ,"arvindarora@gamil.com"]}
#create dataframe
df = pd.DataFrame(data1)

#print dataframe
df
# Out:
#                     Email
# 0       aniketa@gmail.com
# 1      rohitroy@gamil.com
# 2  ranjeetarora@gmail.com
# 3   Kapilsharma@gmail.com
# 4   arvindarora@gamil.com

# %%
#function that used to get username
df['Username'] = df['Email'].str.split('@').str[0]

# %%
df
# Out:
#                     Email      Username
# 0       aniketa@gmail.com       aniketa
# 1      rohitroy@gamil.com      rohitroy
# 2  ranjeetarora@gmail.com  ranjeetarora
# 3   Kapilsharma@gmail.com   Kapilsharma
# 4   arvindarora@gamil.com   arvindarora

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.
#
# For example, if df contains the following values:
#
# A B C
# 0 3 5 1
# 1 8 2 7
# 2 6 9 4
# 3 2 3 5
# 4 9 1 2
#
# Your function should select the following rows: A B C
#
# 1 8 2 7
# 4 9 1 2
#
# The function should return a new DataFrame that contains only the selected rows.

# %%
#import pandas
import pandas as pd

#create dataframe
df = pd.DataFrame({'A': [3, 7, 2, 9, 6],
                   'B': [8, 2, 11, 4, 5],
                   'C': [23, 45, 12, 67, 89]})

#print dataframe
print(df)
# Out:
#    A   B   C
# 0  3   8  23
# 1  7   2  45
# 2  2  11  12
# 3  9   4  67
# 4  6   5  89

# %%
#make a function
def select_rows(df):
    
    # Use boolean indexing to select rows based on conditions
    selected_rows = df[(df['A'] > 5) & (df['B'] < 10)]

# %%
# Call the function to select rows based on conditions
selected_rows = select_rows(df)

# Print the selected rows
print(selected_rows)
# Out:
#    A  B   C
# 1  7  2  45
# 3  9  4  67
# 4  6  5  89

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
#import pandas
import pandas as pd

#create column
data = {'Values' : [12,23,45,67,984,345,32,63,76]}
        
        
#create dataframe
df= pd.DataFrame(data)

#print dataframe
print(df)
# Out:
#    Values
# 0      12
# 1      23
# 2      45
# 3      67
# 4     984
# 5     345
# 6      32
# 7      63
# 8      76

# %%
df.mean()
# Out:
# Values    183.0
# dtype: float64

# %%
df.median()
# Out:
# Values    63.0
# dtype: float64

# %%
df.std()
# Out:
# Values    316.985015
# dtype: float64

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
#import pandas
import pandas as pd

#create columns
data = ({'Sales' : [1234 ,2345,754,3664,3467,6547,3245, 2445,7654,] ,
         'Date': [ '1 march','2 march','3 march','4 march',' 5 march','6 march' , '7 march','8 march','9 march']})

#create dataframe
df = pd.DataFrame(data)

print(df)
# Out:
#    Sales      Date
# 0   1234   1 march
# 1   2345   2 march
# 2    754   3 march
# 3   3664   4 march
# 4   3467   5 march
# 5   6547   6 march
# 6   3245   7 march
# 7   2445   8 march
# 8   7654   9 march

# %%
df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()

# %%
df
# Out:
#    Sales      Date  MovingAverage
# 0   1234   1 march    1234.000000
# 1   2345   2 march    1789.500000
# 2    754   3 march    1444.333333
# 3   3664   4 march    1999.250000
# 4   3467   5 march    2292.800000
# 5   6547   6 march    3001.833333
# 6   3245   7 march    3036.571429
# 7   2445   8 march    3209.571429
# 8   7654   9 march    3968.000000

# %% [raw]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
#
# For example, if df contains the following values:
#
# Date
#
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
#
# Your function should create the following DataFrame:
#
# Date         Weekday
#
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
#
# The function should return the modified DataFrame.

# %%
#import pandas
import pandas as pd

#create column
data = { 'Date' : [ '2023-04-11' , '2023-04-12',' 2023-04-13', '2023-04-14', '2023-04-15', '2023-04-16', '2023-04-17' ,'2023-4-18']}

df= pd.DataFrame(data)

df
# Out:
#           Date
# 0   2023-04-11
# 1   2023-04-12
# 2   2023-04-13
# 3   2023-04-14
# 4   2023-04-15
# 5   2023-04-16
# 6   2023-04-17
# 7    2023-4-18

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['WeekDay'] = df['Date'].dt.dayofweek
df['WeekDay'] = df['Date'].dt.day_name()

# %%
df
# Out:
#         Date    WeekDay
# 0 2023-04-11    Tuesday
# 1 2023-04-12  Wednesday
# 2 2023-04-13   Thursday
# 3 2023-04-14     Friday
# 4 2023-04-15   Saturday
# 5 2023-04-16     Sunday
# 6 2023-04-17     Monday
# 7 2023-04-18    Tuesday

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
#import pandas
import pandas as pd

#create dataframe
df =pd.DataFrame({'date': ["2023-04-27","2023-01-21","2023-04-30","2023-01-15","2023-01-07","2023-04-22","2023-01-27","2023-04-13"]})

#print dataframe
df
# Out:
#          date
# 0  2023-04-27
# 1  2023-01-21
# 2  2023-04-30
# 3  2023-01-15
# 4  2023-01-07
# 5  2023-04-22
# 6  2023-01-27
# 7  2023-04-13

# %%
#update string date into datetime
df['Date'] = pd.to_datetime (df7['date'])

# %%
df
# Out:
#          date       Date
# 0  2023-04-27 2023-04-27
# 1  2023-01-21 2023-01-21
# 2  2023-04-30 2023-04-30
# 3  2023-01-15 2023-01-15
# 4  2023-01-07 2023-01-07
# 5  2023-04-22 2023-04-22
# 6  2023-01-27 2023-01-27
# 7  2023-04-13 2023-04-13

# %%
#selecting date 
df7 = df.loc[df["Date"].between("2023-01-01", "2023-01-31")]

#print  selected date
print(df7)
# Out:
#          date       Date
# 1  2023-01-21 2023-01-21
# 3  2023-01-15 2023-01-15
# 4  2023-01-07 2023-01-07
# 6  2023-01-27 2023-01-27

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?

# %% [markdown]
# ans - The first and foremost library that needs to be imported in order to use the basic functions of pandas is the pandas library itself. The pandas library is a powerful and widely used data manipulation library in Python, and it provides data structures such as DataFrame and Series that are essential for performing data analysis and manipulation tasks.
#
# import pandas as pd
